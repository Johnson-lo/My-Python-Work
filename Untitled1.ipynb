# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Morse_password={"1":"‧────","A":"‧─","K":"─‧─","U":"‧‧─","2":"‧‧───","B":"─‧‧‧","L":"‧─‧‧","V":"‧‧‧─","3":"‧‧‧──","C":"─‧─‧","M":"──","W":"‧──","4":"‧‧‧‧─","D":"─‧‧","N":"─‧","X":"─‧‧─","5":"‧‧‧‧‧","E":"‧","O":"───","Y":"─‧──","6":"─‧‧‧‧","F":"‧‧─‧","P":"‧──‧","Z":"──‧‧","7":"──‧‧‧","G":"──‧","Q":"──‧─","8":"───‧‧","H":"‧‧‧‧","R":"‧─‧","9":"────‧","I":"‧‧","S":"‧‧‧","0":"─────","J":"‧───","T":"─"}
while(True):
    your_word=input("請輸入你想轉換的摩斯密碼,輸入0則結束程式:")
    capital=(your_word.upper())
    if your_word==0:
        print("掰掰")
        break
    else:
        for capital in Morse_password:
            print(capital)
# Out:
# 請輸入你想轉換的摩斯密碼,輸入0則結束程式:ddd
# 1
# A
# K
# U
# 2
# B
# L
# V
# 3
# C
# M
# W
# 4
# D
# N
# X
# 5
# E
# O
# Y
# 6
# F
# P
# Z
# 7
# G
# Q
# 8
# H
# R
# 9
# I
# S
# 0
# J
# T
# 請輸入你想轉換的摩斯密碼,輸入0則結束程式:0
# 1
# A
# K
# U
# 2
# B
# L
# V
# 3
# C
# M
# W
# 4
# D
# N
# X
# 5
# E
# O
# Y
# 6
# F
# P
# Z
# 7
# G
# Q
# 8
# H
# R
# 9
# I
# S
# 0
# J
# T
# 請輸入你想轉換的摩斯密碼,輸入0則結束程式:0
# 1
# A
# K
# U
# 2
# B
# L
# V
# 3
# C
# M
# W
# 4
# D
# N
# X
# 5
# E
# O
# Y
# 6
# F
# P
# Z
# 7
# G
# Q
# 8
# H
# R
# 9
# I
# S
# 0
# J
# T
