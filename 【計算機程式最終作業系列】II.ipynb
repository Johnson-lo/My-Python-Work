# %%
# %tensorflow_version 2.x

import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train0), (x_test, y_test0) = datasets.cifar10.load_data() ##載入資料集
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
name_list = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
idx = np.random.randint(x_train.shape[0])
x_sample = x_train[idx]
y_sample = y_train0[idx].squeeze()

plt.imshow(x_sample)
plt.title(name_list[y_sample])
plt.axis('off');

# %%
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
print("y_train:", y_train0.shape)
print("y_test:", y_test0.shape)
# Out:
# x_train: (50000, 32, 32, 3)
# x_test: (10000, 32, 32, 3)
# y_train: (50000, 1)
# y_test: (10000, 1)

# %%
x_train = x_train / x_train.max()
x_test = x_test / x_test.max()

y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)

# %%
#建(cifar10)神經網路

# %%
CF_CNN_layers_10 = [Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu'),
           MaxPool2D(),
           Conv2D(128, (3, 3), padding='same', activation='relu'),
           MaxPool2D(),
           Conv2D(512, (3, 3), padding='same', activation='relu'),
           GlobalAveragePooling2D()]

# %%
FC_layers = [Dense(units=256, activation='relu'),
       Dense(units=10, activation='softmax')]

# %%
model = Sequential(CF_CNN_layers_10+FC_layers)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 512)         590336
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 762,122
# Trainable params: 762,122
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(),
    metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=5,validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 391/391 [==============================] - 400s 1s/step - loss: 1.7729 - categorical_accuracy: 0.3265 - val_loss: 1.5576 - val_categorical_accuracy: 0.4079
# Epoch 2/5
# 391/391 [==============================] - 403s 1s/step - loss: 1.4403 - categorical_accuracy: 0.4672 - val_loss: 1.3664 - val_categorical_accuracy: 0.4984
# Epoch 3/5
# 391/391 [==============================] - 411s 1s/step - loss: 1.2668 - categorical_accuracy: 0.5383 - val_loss: 1.1876 - val_categorical_accuracy: 0.5571
# Epoch 4/5
# 391/391 [==============================] - 405s 1s/step - loss: 1.1508 - categorical_accuracy: 0.5837 - val_loss: 1.0868 - val_categorical_accuracy: 0.6103
# Epoch 5/5
# 391/391 [==============================] - 414s 1s/step - loss: 1.0673 - categorical_accuracy: 0.6162 - val_loss: 1.0268 - val_categorical_accuracy: 0.6392

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %ls /content/drive
# Out:
# 'My Drive'/

# %%
# %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
# %cd my_ai_data
# Out:
# [Errno 2] No such file or directory: 'my_ai_data'
# /content/drive/My Drive

# %%
# %ls
# Out:
# '108701007 - 複製.rar'
# '1.家教同意書 ~五版.doc'
#  2.就業諮詢表-120.docx
#  33559_英文2.docx
#  36705羅子翔簡歷.gdoc
# '36705羅子翔簡歷 的副本.gdoc'
#  367，羅子翔/
# '3.EXCEL心測 版本120.xlsx'
# '7_7_國立政治大學資訊科學系100學年度轉系公告 (1) (1).gdoc'
# '7_7_國立政治大學資訊科學系100學年度轉系公告 (1).gdoc'
#  CollageMaker_20190321_194416309_1.jpg
# 'data - 複製.zip'
#  image2.gdraw
#  Screenshot_2016-12-16-21-23-28.jpg
#  Screenshot_2017-01-02-19-04-00.jpg
#  Screenshot_2017-01-02-19-08-38.jpg
#  Screenshot_2017-01-02-19-08-46.jpg
#  Screenshot_2017-03-05-11-04-58.jpg
#  Screenshot_2017-03-05-11-15-16.jpg
#  Screenshot_2017-03-05-11-24-28.jpg
#  Screenshot_2017-03-05-17-49-47.jpg
#  Screenshot_2017-03-05-19-32-53.jpg
#  Screenshot_2017-03-05-19-55-04.jpg
#  Screenshot_2017-03-25-23-32-45.jpg
#  Screenshot_2017-04-04-19-18-30.jpg
#  Screenshot_2017-04-14-22-32-54.jpg
#  Untitled0.ipynb
# 'Untitled document.gdoc'
# '不想取名子 WNL.gdraw'
#  中央/
# '備審資料　陳佰承.docx 的副本.gdoc'
#  安樂死.gdoc
#  家教/
#  小組名稱.gdraw
#  彰師/
#  怡豐省颱風潘豐死亡人數攀升至28.docx
#  政大/
# '新建檔案 2019-03-05 23.17.30_23.jpg'
# '新建檔案 2019-03-05 23.17.30.pdf'
# '新建檔案 2019-03-05 23.17.30.zip'
# '新建檔案 2019-03-08 21.27.43_1 (1).jpg'
# '新建檔案 2019-03-08 21.27.43_1.jpg'
# '新建檔案 2019-03-19 15.38.39_1.jpg'
#  有「核」不可.docx
#  有「核」不可.gdoc
#  未命名文件.gdoc
#  水族館1.rar
# '無標題繪圖 (1).gdraw'
#  無標題繪圖.gdraw
#  生命教育作業/
#  程式設計概論.rar
#  自然電影欣賞社報告空白.docx
#  自然電影欣賞社報告範本.docx
#  自然電影欣賞社報告範本.gdoc
#  自然電影欣賞社-羅子翔.gdoc
# '讀書計畫 中央數學.gdoc'
# '讀書計畫 中央通訊.gdoc'
# '讀書計畫 交大應數 的副本.gdoc'
# '讀書計畫 台師大.gdoc'
# '讀書計畫 彰師大.gdoc'
# '讀書計畫 政大應數.gdoc'

# %%
model.save_weights('transfer_HW_cifar10_weight.h5')  # 存在nccu帳號裡

# %%
score_train = model.evaluate(x_train, y_train)
score_test = model.evaluate(x_test, y_test)

print(f'Train Accuracy: {score_train[1]*100}')
print(f'Test Accuracy: {score_test[1]*100}')
# Out:
# 1563/1563 [==============================] - 100s 64ms/step - loss: 1.0043 - categorical_accuracy: 0.6431
# 313/313 [==============================] - 19s 61ms/step - loss: 1.0268 - categorical_accuracy: 0.6392
# Train Accuracy: 64.31199908256531
# Test Accuracy: 63.919997215270996

# %%
(a_train, b_train0), (a_test, b_test0) = datasets.mnist.load_data() #讀入資料集mnist
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
idx = np.random.randint(a_train.shape[0])
a_sample = a_train[idx]
b_sample = b_train0[idx]
plt.imshow(a_sample)
plt.title(b_sample)
plt.axis('off');   #處理

# %%
print("a_train:", a_train.shape)
print("a_test:", a_test.shape)
print("b_train:", b_train0.shape)
print("b_test:", b_test0.shape)
# Out:
# a_train: (60000, 28, 28)
# a_test: (10000, 28, 28)
# b_train: (60000,)
# b_test: (10000,)

# %%
a_train = a_train.reshape(60000, 28, 28, 1)
a_test = a_test.reshape(10000, 28, 28, 1)

# %%
a_train = a_train / a_train.max()
a_test = a_test / a_test.max()

b_train = to_categorical(b_train0, 10)
b_test = to_categorical(b_test0, 10)

# %%
#建mnist
CNN_layers = [Conv2D(28, (3, 3), input_shape=(28, 28, 1), padding='same', activation='relu'),
        MaxPool2D(),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        MaxPool2D(),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        GlobalAveragePooling2D()]

# %%
FC_layers = [Dense(units=256, activation='relu'),
       Dense(units=10, activation='softmax')]

# %%
model_10 = Sequential(CNN_layers+FC_layers)
model_10.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 28)        280
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 28)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        16192
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 125,922
# Trainable params: 125,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in FC_layers:
    layer.train = False

# %%
#評量指標
model_10.compile(
    loss='categorical_crossentropy', 
    optimizer=Adam(), 
    metrics=['categorical_accuracy'])

# %%
# 訓練
model_10.fit(a_train, b_train, batch_size=128, epochs=5, validation_data=(a_test, b_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 83s 178ms/step - loss: 0.7151 - categorical_accuracy: 0.7657 - val_loss: 0.2980 - val_categorical_accuracy: 0.9056
# Epoch 2/5
# 469/469 [==============================] - 84s 179ms/step - loss: 0.2141 - categorical_accuracy: 0.9351 - val_loss: 0.1730 - val_categorical_accuracy: 0.9453
# Epoch 3/5
# 469/469 [==============================] - 84s 179ms/step - loss: 0.1577 - categorical_accuracy: 0.9519 - val_loss: 0.1057 - val_categorical_accuracy: 0.9677
# Epoch 4/5
# 469/469 [==============================] - 84s 178ms/step - loss: 0.1197 - categorical_accuracy: 0.9625 - val_loss: 0.0943 - val_categorical_accuracy: 0.9699
# Epoch 5/5
# 469/469 [==============================] - 86s 184ms/step - loss: 0.0983 - categorical_accuracy: 0.9695 - val_loss: 0.1006 - val_categorical_accuracy: 0.9667

# %%
# %ls /content/drive
# Out:
# 'My Drive'/

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
# %cd my_ai_data
# Out:
# /content/drive/My Drive/my_ai_data

# %%
# %ls

# %%
model.save_weights('transfer_HW_mnist_weight.h5')  # 存在nccu帳號裡

# %%
score_train_2 = model_10.evaluate(a_train, b_train)
score_test_2 = model_10.evaluate(a_test, b_test)

print(f'Train Accuracy: {score_train_2[1]*100}')
print(f'Test Accuracy: {score_test_2[1]*100}')
# Out:
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.1146 - categorical_accuracy: 0.9648
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1006 - categorical_accuracy: 0.9667
# Train Accuracy: 96.48000001907349
# Test Accuracy: 96.670001745224
